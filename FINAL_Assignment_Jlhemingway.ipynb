# %%
import pandas as pd

# %%
import numpy as np

# %%
#loading the dataset
movies = pd.read_csv('/Users/jesse/Downloads/2010-2023 Movies Box Office Collection.csv')

# %%
#exploratory data analysis
    #info and datatypes
    #note: no null/missing values
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              2800 non-null   int64
#  1   Release Group     2800 non-null   object
#  2   Worldwide         2800 non-null   object
#  3   Domestic          2800 non-null   object
#  4   Domestic_percent  2800 non-null   object
#  5   Foreign           2800 non-null   object
#  6   Foreign_percent   2800 non-null   object
#  7   year              2800 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 175.1+ KB

# %%
    #rows, columns
movies.shape
# Out:
# (2800, 8)

# %%
    #index
movies.index
# Out:
# RangeIndex(start=0, stop=2800, step=1)

# %%
#subsets
    #subset year
year_sub = movies['year']
year_sub
# Out:
# 0       2010
# 1       2010
# 2       2010
# 3       2010
# 4       2010
#         ...
# 2795    2023
# 2796    2023
# 2797    2023
# 2798    2023
# 2799    2023
# Name: year, Length: 2800, dtype: int64

# %%
    #subset Domestic
domestic_sub = movies[['Rank','Release Group','Domestic','Domestic_percent','year']]
domestic_sub
# Out:
#       Rank                                      Release Group      Domestic  \
# 0        0                                        Toy Story 3  41,50,04,880
# 1        1                                Alice in Wonderland  33,41,91,110
# 2        2       Harry Potter and the Deathly Hallows: Part 1  29,59,83,305
# 3        3                                          Inception  29,25,76,195
# 4        4                                Shrek Forever After  23,87,36,787
# ...    ...                                                ...           ...
# 2795   195                             On the Wandering Paths             0
# 2796   196                                     Weekend Rebels             0
# 2797   197                                           Ransomed      1,42,101
# 2798   198  Checker Tobi und die Reise zu den fliegenden F...             0
# 2799   199                                 The Silent Service             0
#
#      Domestic_percent  year
# ...

# %%
    #subset Foreign
foreign_sub = movies[['Rank','Release Group','Foreign','Foreign_percent','year']]
foreign_sub
# Out:
#       Rank                                      Release Group       Foreign  \
# 0        0                                        Toy Story 3  65,19,64,823
# 1        1                                Alice in Wonderland  69,12,76,000
# 2        2       Harry Potter and the Deathly Hallows: Part 1  66,43,00,000
# 3        3                                          Inception  53,56,82,500
# 4        4                                Shrek Forever After  51,38,64,080
# ...    ...                                                ...           ...
# 2795   195                             On the Wandering Paths     81,87,125
# 2796   196                                     Weekend Rebels     81,84,539
# 2797   197                                           Ransomed     79,59,533
# 2798   198  Checker Tobi und die Reise zu den fliegenden F...     79,53,344
# 2799   199                                 The Silent Service     78,36,539
#
#      Foreign_percent  year
# 0             61.10%  2010
# ...

# %%
#changing data types
movies['Worldwide'] = movies['Worldwide'].str.replace(',', '').astype(int)
movies['Domestic'] = movies['Domestic'].str.replace(',', '').astype(int)
movies['Foreign'] = movies['Foreign'].str.replace(',', '').astype(int)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              2800 non-null   int64
#  1   Release Group     2800 non-null   object
#  2   Worldwide         2800 non-null   int64
#  3   Domestic          2800 non-null   int64
#  4   Domestic_percent  2800 non-null   object
#  5   Foreign           2800 non-null   int64
#  6   Foreign_percent   2800 non-null   object
#  7   year              2800 non-null   int64
# dtypes: int64(5), object(3)
# memory usage: 175.1+ KB

# %%
#grouping and aggregation
    #df summary
movies.describe()
# Out:
#               Rank     Worldwide      Domestic       Foreign         year
# count  2800.000000  2.800000e+03  2.800000e+03  2.800000e+03  2800.000000
# mean     99.500000  1.352524e+08  4.528077e+07  8.997098e+07  2016.500000
# std      57.744618  2.264251e+08  8.515878e+07  1.521462e+08     4.031849
# min       0.000000  4.810790e+06  0.000000e+00  0.000000e+00  2010.000000
# 25%      49.750000  2.739098e+07  0.000000e+00  1.797282e+07  2013.000000
# 50%      99.500000  5.213248e+07  1.423254e+07  3.565625e+07  2016.500000
# 75%     149.250000  1.362965e+08  5.335140e+07  8.793205e+07  2020.000000
# max     199.000000  2.799439e+09  9.366622e+08  1.941066e+09  2023.000000

# %%
    #group by year
year_grp = movies.groupby(['year'])
# Out:
#       Rank                                  Release Group   Worldwide  \
# 0        0                                    Toy Story 3  1066969703
# 1        1                            Alice in Wonderland  1025467110
# 2        2   Harry Potter and the Deathly Hallows: Part 1   960283305
# 3        3                                      Inception   828258695
# 4        4                            Shrek Forever After   752600867
# ...    ...                                            ...         ...
# 2605     5            Spider0Man: Across the Spider0Verse   690615475
# 2606     6                                          Wonka   632302312
# 2607     7                             The Little Mermaid   569626289
# 2608     8  Mission: Impossible 0 Dead Reckoning Part One   567535383
# 2609     9                                      Elemental   496444308
#
#        Domestic Domestic_percent    Foreign Foreign_percent  year
# ...

# %%
#Question 1: did movies perform better domestically or internationally from 2010-2023?
domestic_sub['Domestic'].sum
# Out:
# <bound method Series.sum of 0       41,50,04,880
# 1       33,41,91,110
# 2       29,59,83,305
# 3       29,25,76,195
# 4       23,87,36,787
#             ...
# 2795               0
# 2796               0
# 2797        1,42,101
# 2798               0
# 2799               0
# Name: Domestic, Length: 2800, dtype: object>

# %%
foreign_sub['Foreign'].sum
# Out:
# <bound method Series.sum of 0       65,19,64,823
# 1       69,12,76,000
# 2       66,43,00,000
# 3       53,56,82,500
# 4       51,38,64,080
#             ...
# 2795       81,87,125
# 2796       81,84,539
# 2797       79,59,533
# 2798       79,53,344
# 2799       78,36,539
# Name: Foreign, Length: 2800, dtype: object>

# %%
#Question 2: which year grossed the most total worldwide
year_grp['Worldwide'].agg(['median', 'mean', 'max', 'sum']).sort_values(by=['sum'], ascending=[False])
# Out:
#           median          mean         max          sum
# year
# 2019  63349461.0  1.771393e+08  2799439100  35427854208
# 2017  60999583.0  1.710457e+08  1332539889  34209146582
# 2018  73714586.5  1.706797e+08  2048359754  34135939193
# 2015  72145657.0  1.637093e+08  2068223624  32741853312
# 2016  75353022.5  1.618727e+08  1153296293  32374542002
# 2014  72084134.0  1.500526e+08  1104054072  30010529897
# 2012  61663992.0  1.475370e+08  1518812988  29507398427
# 2013  68552764.5  1.453878e+08  1280802282  29077554568
# 2011  62458932.5  1.346257e+08  1341511219  26925147932
# 2010  60706384.5  1.278503e+08  1066969703  25570061807
# 2023  32431771.5  1.078035e+08  1445638421  21560692459
# 2022  21745864.0  1.043728e+08  2320250281  20874564107
# 2021  26511473.0  9.124814e+07  1912233593  18249627473
# 2020  12023268.0  4.020858e+07   461421559   8041716369

# %%
#Question 3: what were the top 10 movies of 2010-2023
top10 = movies.sort_values(by=['Worldwide'], ascending=[False])
top10.head(10)
# Out:
#       Rank                               Release Group   Worldwide   Domestic  \
# 1800     0                           Avengers: Endgame  2799439100  858373000
# 2400     0                    Avatar: The Way of Water  2320250281  684075767
# 1000     0  Star Wars: Episode VII 0 The Force Awakens  2068223624  936662225
# 1600     0                      Avengers: Infinity War  2048359754  678815482
# 2200     0                     Spider0Man: No Way Home  1912233593  804793477
# 1001     1                              Jurassic World  1670400637  652270625
# 1801     1                               The Lion King  1656943394  543638043
# 400      0                                The Avengers  1518812988  623357910
# 1002     2                                   Furious 7  1515047671  353007020
# 2401     1                           Top Gun: Maverick  1495696292  718732821
#
#      Domestic_percent     Foreign Foreign_percent  year
# ...

# %%
year_grp['Foreign'].agg(['median', 'mean', 'max', 'sum'])
# Out:
#           median          mean         max          sum
# year
# 2010  39000664.0  7.900521e+07   691276000  15801042769
# 2011  40412031.0  8.576729e+07   960500000  17153458132
# 2012  35672699.5  9.352669e+07   895455078  18705337220
# 2013  43771597.5  9.376599e+07   880064273  18753198930
# 2014  48531318.5  9.948568e+07   858614996  19897135408
# 2015  49395600.5  1.097644e+08  1162040651  21952888620
# 2016  50179229.0  1.079254e+08   745211944  21585087147
# 2017  46146686.5  1.182041e+08  1009996733  23640825704
# 2018  45414264.0  1.162793e+08  1369544272  23255863955
# 2019  46103861.5  1.221034e+08  1941066100  24420683635
# 2020  10269563.5  3.363644e+07   461048804   6727287414
# 2021  19485375.0  6.764874e+07  1107440116  13529748239
# 2022  18646001.0  6.708493e+07  1636174514  13416986260
# 2023  21155312.5  6.539604e+07   809400000  13079208492

# %%
#Summarize your findings from the aggregation, filtering, and transformation operations. What did you learn about your dataset? What challenges did you encounter?

# %%
#summary statistic for numerical columns within each group
#year_grp['Worldwide'].describe()
